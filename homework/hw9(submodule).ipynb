# %%
import numpy as np

# %% [markdown]
# 1. 证明：集合函数$f:\ 2 ^ V \rightarrow R$是一个子模函数，当且仅当对于所有的$S \subseteq T \subseteq V, C \subseteq V \setminus T$,
# $$
# f(S \cup C) - f(S) \ge f(T \cup C) - f(T)
# $$

# %% [markdown]
# ![8bb4ff9f696a3568303edbda8ccab50.jpg](attachment:8bb4ff9f696a3568303edbda8ccab50.jpg)

# %% [markdown]
# 3. 给定一个集合V，当$A \subseteq V$时，$f(A)$ 是一个子模函数。
#
# （1）证明：$\bar{f}(A) = f(A^c)$是一个子模函数。
#
# （2）证明：当$S \subset V, g(A) = f(A \cap S)$是一个子模函数。

# %% [markdown]
# ![adbe2fea5004cef4ada9bb09ac330d3.jpg](attachment:adbe2fea5004cef4ada9bb09ac330d3.jpg)

# %% [markdown]
# ![00b16acb36b5092ba5dbacbb7af7149.jpg](attachment:00b16acb36b5092ba5dbacbb7af7149.jpg)

# %% [markdown]
# 5. 令$\omega : \Omega \rightarrow \mathop{R}$，以及任意$A \subset \Omega$, 验证
#
# $$
# F(A) =
# \begin{cases}
# \mathop{max}\limits_{a \in A} w_a,& A \ne \varnothing \\
# c , & 其他
# \end{cases}
# $$
# 是一个集合函数。如果$c \le \mathop{max}\limits_{a \in \Omega} w_a$,试证明集合函数F试一个子模函数。

# %% [markdown]
# ![338e80e8b21467a88424e25e2c089cf.jpg](attachment:338e80e8b21467a88424e25e2c089cf.jpg)

# %% [markdown]
# 12. 假设全集$U = \{ 1,2,3,4,5 \}$和子集族
# $$
# S = \{ \{1,2\}, \{ 1,2,4\}, \{ 2,3 \}, \{ 4,5 \}, \{ 3\}, \{ 1,5 \}  \}
# $$
# 当$k = 2$时，运用爬山算法求解最大覆盖问题，可能的解有哪些？

# %% [markdown]
# ![162007bbc2cd93bada3fba1b23c3889.jpg](attachment:162007bbc2cd93bada3fba1b23c3889.jpg)
