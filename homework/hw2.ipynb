# %% [markdown]
# 1. 已知随机变量X的期望$\mu = E(X)$和方差$\sigma^2 = E[(X - \mu)^2]$。如果定义随机变量$X^* = \frac{X - \mu}{\sigma}$,证明
#
# $$
# P[|X^*| \ge x] \le \frac{1}{c^2}
# $$

# %% [markdown]
# ![63aec9a85df006f468137b979964fe5.jpg](attachment:63aec9a85df006f468137b979964fe5.jpg)

# %% [markdown]
# 2. 令$X_i(i = 1,2,...,n)$为一组独立同分布的随机变量，期望$\mu = E(X_i)$和方差$\sigma^2 = E[(X_i - \mu)^2]$。如果定义$\bar{X} = \frac{1}{n}\sum\limits_{i=1}^nX_i$,证明
# $$
# P[|\bar{X} - \mu| \ge \epsilon] \le \frac{\sigma^2}{n\epsilon^2}
# $$

# %% [markdown]
# ![724e43a0cd19670bfbd818503fa049e.jpg](attachment:724e43a0cd19670bfbd818503fa049e.jpg)

# %% [markdown]
# 3. 假设抛一枚均匀的硬币n次，随机变量X定义为正面朝上的次数。
#
# （1）运用Chebyshev不等式给出事件$X < \frac{n}{4}$的概率上界
#
# （2）运用Chenoff不等式给出事件$X < \frac{n}{4}$的概率上界

# %% [markdown]
# ![94d03e3c6fcaae2d15eb1f1347065ab.jpg](attachment:94d03e3c6fcaae2d15eb1f1347065ab.jpg)

# %% [markdown]
# 4. 假设$X_i$独立随机变量序列满足$P(X_i = 1) = p_i$ 和 $P(X_i = 0) = 1 - p_i$,令$\mu = \sum\limits_{i=1}^np_i$,定义随机变量$X = \sum_{i = 1}^nX_i$。证明以下结论：
#
# (1) $P(X > (1 + \delta)\mu) < \large(\frac{e^{\delta}} {(1 + \delta)^{(1 + \delta)}})^\mu$
#
# (2) $P(X > (1 + \delta)\mu) < \normalsize{ exp(\frac{-\mu \delta^2} {3})}$

# %% [markdown]
# ![30b9f2ce71f843e986bb37ef49640cc.jpg](attachment:30b9f2ce71f843e986bb37ef49640cc.jpg)

# %% [markdown]
# ![e52f41166f082343f0a96c16bd228cf.jpg](attachment:e52f41166f082343f0a96c16bd228cf.jpg)

# %% [markdown]
# 5. 假设$X_i$独立随机变量序列满足$P(X_i = 1) = p_i$和$P(X_i = 0) = 1 - p_i$,令$\mu = \sum\limits_{i=1}^{n}p_i$，定义随机变量$X=\sum\limits_{i=1}^{n}X_i$。证明
# $$
# P(|X-\mu| > \delta\mu) < 2exp(\frac{-\mu\delta^2}{3})
# $$

# %% [markdown]
# ![d204d208096f4783e65e6ced417bbb3.jpg](attachment:d204d208096f4783e65e6ced417bbb3.jpg)

# %% [markdown]
# 6. 设一组独立随机变量$X_i \sim Bernoulli(p)$,其中$i = 1,\cdots,n$。令$\bar{X} = \frac{1}{n}\sum\limits_{i=1}^nX_i$。试回答当n取值为多少时，使得
# $$
# P(|\bar{X} - p| \le \epsilon p) \ge 1 - \delta
# $$

# %% [markdown]
# ![a6801668be3ff1ac70d575aa50f2586.jpg](attachment:a6801668be3ff1ac70d575aa50f2586.jpg)
